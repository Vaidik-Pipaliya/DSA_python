# %% [markdown]
# ## syntax:
# def func_name(paramaters):
#     #logics
#     return expression

# %%
num = 24
if num%2==0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
#now we will make function
# Out:
# 24 is even

# %% [markdown]
# # Approach: Simple Conditional check
#
# ## Problem Explanation
#
# Checks if a hardcoded number `num` is even or odd and prints the result.
#
# ## Approach Used
#
# * **Technique:** Simple Conditional check.
# * **Why it works:** If a number is divisible by 2 with no remainder, it is even. otherwise, it is odd.
# * **Key Idea:** Modulo division by 2.
#
# ## Dry Run
#
# Input: `num = 24`
# * `num % 2 == 0` -> `24 % 2` is `0`.
# * Condition is `True`.
# * Prints: `24 is even`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Execution takes constant time.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; No extra variables or data structures.
# </div>

# %%
def even_odd(num):
    """this will finds even or odd nummbers"""
    if num%2==0:
        print(f"{num} is even")
    else:
        print(f"{num} is odd")

# %% [markdown]
# # Approach: Function encapsulation of modulo conditional logic
#
# ## Problem Explanation
#
# Defines a function `even_odd` that takes a number and prints whether it is even or odd.
#
# ## Approach Used
#
# * **Technique:** Function encapsulation of modulo conditional logic.
# * **Why it works:** Wraps the even/odd conditional logic in a reusable function block with a docstring.
# * **Key Idea:** Parameterized code execution.
#
# ## Dry Run
#
# Function Definition:
# * Accepts argument `num`.
# * If `num % 2 == 0`, prints even, else odd.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Runs in constant time when called.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Uses minimal constant space.
# </div>

# %%
##calling function
even_odd(5)
# Out:
# 5 is odd

# %% [markdown]
# # Approach: Function invocation
#
# ## Problem Explanation
#
# Executes the previously defined `even_odd` function with the argument `5`.
#
# ## Approach Used
#
# * **Technique:** Function invocation.
# * **Why it works:** Calls the defined function with an integer parameter.
# * **Key Idea:** Reusable execution.
#
# ## Dry Run
#
# Input: `even_odd(5)`
# * Argument `num = 5`.
# * `5 % 2 == 0` is `False`.
# * Prints: `5 is odd`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Single execution of conditional statements.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; No memory overhead.
# </div>

# %%
def sum(a,b):
    return a+b


result = sum(1,2)
print(f"{result}")
# Out:
# 3

# %% [markdown]
# # Approach: Parameterized addition and value return
#
# ## Problem Explanation
#
# Defines a sum function that adds two numbers and returns the result, then invokes it.
#
# ## Approach Used
#
# * **Technique:** Parameterized addition and value return.
# * **Why it works:** Takes two inputs, evaluates their sum, and passes the result back to the caller.
# * **Key Idea:** Value returning function.
#
# ## Dry Run
#
# Input: `sum(1, 2)`
# * `a = 1`, `b = 2`
# * Returns `1 + 2 = 3`
# * Prints: `3`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Performs a single arithmetic operation.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Minimal local variables.
# </div>

# %%
##variable length arguments(*)
#postional arguments

def print_num(*args):
    for num in args:
        print(num)
print_num(1,2,3,4,5,"vaidik")
# Out:
# 1
# 2
# 3
# 4
# 5
# vaidik

# %% [markdown]
# # Approach: Variable length arguments (`*args`)
#
# ## Problem Explanation
#
# Defines a function `print_num` that accepts a variable number of positional arguments using `*args` and prints them one by one.
#
# ## Approach Used
#
# * **Technique:** Variable length arguments (`*args`).
# * **Why it works:** In Python, `*args` packs all positional arguments into a tuple, which can then be iterated over.
# * **Key Idea:** Collect a variable number of positional parameters.
#
# ## Dry Run
#
# Input: `print_num(1, 2, 3, 4, 5, "vaidik")`
# * `args` becomes tuple: `(1, 2, 3, 4, 5, "vaidik")`
# * Iterates through the tuple and prints each item.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(M)</span> &mdash; Where `M` is the number of arguments passed to the function.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(M)</span> &mdash; To store the tuple of arguments.
# </div>

# %%
# keyword arguments(**), key-value pair of parameters
def print_detail(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")
print_detail(name="vd",agg=32,city="pune")
# Out:
# name:vd
# agg:32
# city:pune

# %% [markdown]
# # Approach: Variable keyword arguments (`**kwargs`)
#
# ## Problem Explanation
#
# Defines a function `print_detail` that accepts keyword arguments using `**kwargs` and prints them as key-value pairs.
#
# ## Approach Used
#
# * **Technique:** Variable keyword arguments (`**kwargs`).
# * **Why it works:** `**kwargs` packs keyword arguments into a dictionary. We iterate over key-value pairs using `.items()`.
# * **Key Idea:** Collect dictionary-like variable parameters.
#
# ## Dry Run
#
# Input: `print_detail(name="vd", agg=32, city="pune")`
# * `kwargs` becomes: `{'name': 'vd', 'agg': 32, 'city': 'pune'}`
# * Loop outputs key-value pairs.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(K)</span> &mdash; Where `K` is the number of keyword arguments.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(K)</span> &mdash; To store the keyword argument dictionary.
# </div>

# %%
#combining both
def print_details(*args,**kwargs):
    for val in args:
        print(f" positional args:-{val}")

    for key,value in kwargs.items():
        print(f"key word args:-{key}:{value}")

print_details(1,2,3,4,5,"vd",name="vd",agg=32,city="pune")
# Out:
#  positional args:-1
#  positional args:-2
#  positional args:-3
#  positional args:-4
#  positional args:-5
#  positional args:-vd
# key word args:-name:vd
# key word args:-agg:32
# key word args:-city:pune

# %% [markdown]
# # Approach: Combined `*args` and `**kwargs`
#
# ## Problem Explanation
#
# Defines and calls a function `print_details` that combines both positional (`*args`) and keyword (`**kwargs`) variable arguments.
#
# ## Approach Used
#
# * **Technique:** Combined `*args` and `**kwargs`.
# * **Why it works:** Positional parameters are captured in `args` tuple, while named/keyword parameters are captured in `kwargs` dict.
# * **Key Idea:** Full argument list collection.
#
# ## Dry Run
#
# Input: `print_details(1, 2, 3, 4, 5, "vd", name="vd", agg=32, city="pune")`
# * `args` tuple: `(1, 2, 3, 4, 5, "vd")`
# * `kwargs` dict: `{'name': 'vd', 'agg': 32, 'city': 'pune'}`
# * Loops print elements of `args` then items of `kwargs`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(M + K)</span> &mdash; Proportional to the total number of arguments.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(M + K)</span> &mdash; To store the tuple and dictionary objects.
# </div>

# %%
###returned statment , NOTE: SUPPORTS MULTIPLE PARAMETERES ALSO
def multi(a,b):
    return a*b,a,a-b

multi(2,3)
# Out:
# (6, 2, -1)

# %% [markdown]
# # Approach: Multiple value return
#
# ## Problem Explanation
#
# Defines a function `multi` that returns multiple values (product, first term, and difference) as a tuple.
#
# ## Approach Used
#
# * **Technique:** Multiple value return.
# * **Why it works:** Python automatically packs multiple comma-separated values in a return statement into a single tuple.
# * **Key Idea:** Return a structured tuple.
#
# ## Dry Run
#
# Input: `multi(2, 3)`
# * `a = 2`, `b = 3`
# * Returns: `(2 * 3, 2, 2 - 3)` -> `(6, 2, -1)`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Arithmetic evaluations are constant time.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Constant memory allocation.
# </div>
