# %%
numbers=[1,2,3,4,5]
lambda x:x**2,numbers
map(lambda x:x**2,numbers)
list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# # Approach: `map` with lambda
#
# ## Problem Explanation
#
# Applies a lambda function that squares each number to a list of numbers using `map()`.
#
# ## Approach Used
#
# * **Technique:** `map` with lambda.
# * **Why it works:** `map` applies the squaring lambda function to each item of the collection iteratively.
# * **Key Idea:** Mapping square transformation.
#
# ## Dry Run
#
# Input: `numbers = [1, 2, 3, 4, 5]`
# * Squares: `1**2 = 1`, `2**2 = 4`, `3**2 = 9`, `4**2 = 16`, `5**2 = 25`.
# * Output: `[1, 4, 9, 16, 25]`
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; Maps elements in linear sequence.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; List creation for outputs.
# </div>

# %% [markdown]
# ### steps
# list(map(lambda))

# %%
def square(x):
    return x**2
print(square(10))
# Out:
# 100

# %% [markdown]
# # Approach: Arithmetic function
#
# ## Problem Explanation
#
# Defines a standard squaring function.
#
# ## Approach Used
#
# * **Technique:** Arithmetic function.
# * **Why it works:** Evaluates square exponent.
# * **Key Idea:** Squaring.
#
# ## Dry Run
#
# Input: `10`
# * Returns `100`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Constant arithmetic time.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Constant space.
# </div>

# %%
list1 = [2,3,4,5,6,7]
list(map(square,list1))
# Out:
# [4, 9, 16, 25, 36, 49]

# %% [markdown]
# # Approach: `map` with named function
#
# ## Problem Explanation
#
# Applies the standard squaring function `square` to a list of numbers using `map()`.
#
# ## Approach Used
#
# * **Technique:** `map` with named function.
# * **Why it works:** Invokes `square` function sequentially across the list.
# * **Key Idea:** Mapping custom functions.
#
# ## Dry Run
#
# Input: `list1 = [2, 3]`
# * Evaluates `square(2) = 4` and `square(3) = 9`.
# * Output: `[4, 9]`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; N operations.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; Output array storage.
# </div>

# %%
num1=[1,2,3,4,5]
num2=[10,20,30,40,50]
print(list(map(lambda x,y:x+y,num1,num2)))
# Out:
# [11, 22, 33, 44, 55]

# %% [markdown]
# # Approach: Multi-list mapping
#
# ## Problem Explanation
#
# Applies an addition lambda function element-wise across two lists.
#
# ## Approach Used
#
# * **Technique:** Multi-list mapping.
# * **Why it works:** `map` extracts elements from both lists at matching indices and feeds them into the lambda.
# * **Key Idea:** Element-wise pairwise list addition.
#
# ## Dry Run
#
# Input: `num1 = [1, 2]`, `num2 = [10, 20]`
# * Pair 1: `1 + 10 = 11`.
# * Pair 2: `2 + 20 = 22`.
# * Output: `[11, 22]`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; Linear execution across lists of size N.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; To store output list.
# </div>

# %%
#convert list of string into int
li1=['1','2','3','4']
st=list(map(int,li1))
print(st)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Approach: Type-casting map
#
# ## Problem Explanation
#
# Converts a list of string numbers to integers using `map` and Python's built-in `int` class constructor.
#
# ## Approach Used
#
# * **Technique:** Type-casting map.
# * **Why it works:** Applies `int()` conversion to each string element.
# * **Key Idea:** List type-casting.
#
# ## Dry Run
#
# Input: `['1', '2']`
# * Converts `'1'` to `1`, `'2'` to `2`.
# * Output: `[1, 2]`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; Process each string element.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; To store integer elements.
# </div>

# %%
#uppercase
str1=['apple']
ans=list(map(str.upper,str1))
print(ans)
# Out:
# ['APPLE']

# %% [markdown]
# # Approach: Mapping built-in string methods
#
# ## Problem Explanation
#
# Converts lowercase string elements in a list to uppercase using `map` and `str.upper`.
#
# ## Approach Used
#
# * **Technique:** Mapping built-in string methods.
# * **Why it works:** Calls upper method on each string element in the list.
# * **Key Idea:** String transformation.
#
# ## Dry Run
#
# Input: `['apple']`
# * `str.upper('apple')` is `'APPLE'`.
# * Output: `['APPLE']`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N * L)</span> &mdash; N items of average length L.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N * L)</span> &mdash; For the upper-cased output strings list.
# </div>

# %%
def uppeer(st):
    return str.upper(st)
uppeer("abc")

#using map
list1=["apple","banana","graps","watermelon"]
ans=list(map(str.upper,list1))
print(ans)
# Out:
# ['APPLE', 'BANANA', 'GRAPS', 'WATERMELON']

# %% [markdown]
# # Approach: Mapping string conversion
#
# ## Problem Explanation
#
# Converts list of strings to uppercase using `map` and `str.upper`.
#
# ## Approach Used
#
# * **Technique:** Mapping string conversion.
# * **Why it works:** Applies `str.upper` method across the collection elements.
# * **Key Idea:** Capitalize string collections.
#
# ## Dry Run
#
# Input: `["apple", "banana"]`
# * Becomes: `["APPLE", "BANANA"]`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N * L)</span> &mdash; String processing proportional to characters.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N * L)</span> &mdash; Uppercase list storage.
# </div>

# %%
def get_age(person):
    return person["age"]
people=[
    {"name":"vaidik", "age":18},
    {"name":"vd", "age":20}
]
print(ans)
# Out:
# [18, 20]

# %% [markdown]
# # Approach: Key getter mapping reference
#
# ## Problem Explanation
#
# Demonstrates defining a getter function `get_age` and outlines using it to extract properties from a list of dictionaries.
#
# ## Approach Used
#
# * **Technique:** Key getter mapping reference.
# * **Why it works:** Returns key value of dictionaries. Note that the print statement prints `ans` variable which was defined in previous cell.
# * **Key Idea:** Record key retrieval.
#
# ## Dry Run
#
# Input: `people` list.
# * Code prints `ans` variable which was defined in previous cell as `['APPLE', 'BANANA', 'GRAPS', 'WATERMELON']`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Evaluates print statement of predefined variable.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; No extra data structures created.
# </div>
