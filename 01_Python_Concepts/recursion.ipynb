# %%
#print x , n number of time

# %%
def func(x,n):
    if n == 0:
        return 
    print(x)
    func(x,n-1)
func(15,3)
# Out:
# 15
# 15
# 15

# %% [markdown]
# # Approach: Recursion
#
# ## Problem Explanation
#
# Recursively prints a value `x`, `n` times.
#
# ## Approach Used
#
# * **Technique:** Recursion.
# * **Why it works:** Decrements count `n` on each recursive call, printing `x` and returning when `n` reaches `0` (base case).
# * **Key Idea:** Base-case driven recursive stack execution.
#
# ## Dry Run
#
# Input: `func(15, 3)`
# * `n = 3`: Prints `15`. Calls `func(15, 2)`.
# * `n = 2`: Prints `15`. Calls `func(15, 1)`.
# * `n = 1`: Prints `15`. Calls `func(15, 0)`.
# * `n = 0`: Returns immediately.
# * Recursion completes.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(n)</span> &mdash; The function runs exactly `n` recursive steps.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(n)</span> &mdash; Utilizes `n` stack frames for the recursion.
# </div>
