# %%
class solution(object):
    def fib(self,n):
        if n  == 0  or n ==1:
            return n
        return self.fib(n-1) + self.fib(n-2)
obj = solution()
print(obj.fib(10))
# Out:
# 55

# %% [markdown]
# # Approach: Recursion
#
# ## Problem Explanation
#
# Calculates the Fibonacci number at index `n` using standard recursion.
#
# ## Approach Used
#
# * **Technique:** Recursion.
# * **Why it works:** Evaluates Fibonacci sequence recursively using the relation `F(n) = F(n-1) + F(n-2)` with base cases `F(0) = 0` and `F(1) = 1`.
# * **Key Idea:** Branching recursion.
#
# ## Dry Run
#
# Input: `fib(3)`
# * `fib(3)` returns `fib(2) + fib(1)`
# * `fib(2)` returns `fib(1) + fib(0)`
# * `fib(1)` returns `1`, `fib(0)` returns `0`. `fib(2) = 1 + 0 = 1`.
# * `fib(3) = 1 + 1 = 2`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #d9534f; background-color: #f2dede; color: #a94442; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #d9534f; font-weight: bold;">O(2^N)</span> &mdash; Each call splits into two child calls, forming a recursion tree of exponential height.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; Depth of the recursive call stack is proportional to `N`.
# </div>
