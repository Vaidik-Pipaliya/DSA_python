# %%
def palindrome(num):
    original = num
    result = 0

    while num > 0:
        last_digit = num % 10
        result = result * 10 + last_digit
        num = num // 10

    if original == result:
        return True
    else:
        return False

print(palindrome(121))
print(palindrome(-123))
# Out:
# True
# False
