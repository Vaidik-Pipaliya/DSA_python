# %%
def fun(n):
    if n == 1:
        return 1
    return n + fun(n-1)
fun(5)
# Out:
# 120

# %% [markdown]
# # Approach: Recursion
#
# ## Problem Explanation
#
# Calculates the sum of first `n` natural numbers using recursion.
#
# ## Approach Used
#
# * **Technique:** Recursion.
# * **Why it works:** Recursively defines sum as `n + sum(n-1)` with the base case returning `1` when `n = 1`.
# * **Key Idea:** Accumulation via call stack.
#
# ## Dry Run
#
# Input: `fun(5)`
# * `fun(5) = 5 + fun(4)`
# * `fun(4) = 4 + fun(3)`
# * `fun(3) = 3 + fun(2)`
# * `fun(2) = 2 + fun(1)`
# * `fun(1)` returns `1`.
# * Reconstructs: `5 + 4 + 3 + 2 + 1 = 15`.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; Performs `N` recursive function calls.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(N)</span> &mdash; Stack frame depth is equal to `N`.
# </div>
