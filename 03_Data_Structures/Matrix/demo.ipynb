# %%
#matrix:- 
nums = [[5,20,3],[7,-10,9],[1,-52,6]]
row = len(nums)
col = len(nums[0])
for i in range(0,row):
    for j in range(0,col):
        print(nums[i][j],end=" ")
    print()
# Out:
# 5 20 3
# 7 -10 9
# 1 -52 6
