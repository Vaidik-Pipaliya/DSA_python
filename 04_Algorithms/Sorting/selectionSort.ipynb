# %%
def selection_sort(num):
    n=len(num)
    for i in range(0,num):
        min_index = i
        for j in range(i+1,n):
            if num[j]<num[min_index]:
                min_index = j
        num[i],num[min_index] = num[min_index],num[i]

# %% [markdown]
# # Approach: Selection Sort (Buggy implementation)
#
# ## Problem Explanation
#
# Sorts an array in ascending order using Selection Sort. Note that this implementation contains a bug in the outer loop range statement (`range(0, num)` where `num` is the input list, raising a `TypeError`).
#
# ## Approach Used
#
# * **Technique:** Selection Sort (Buggy implementation).
# * **Why it works:** In each pass, it attempts to find the minimum element in the unsorted suffix and swap it with the element at the current boundaries index.
# * **Key Idea:** Select minimum and swap.
#
# ## Dry Run
#
# Input: `num = [3, 1, 2]`
# * `n = 3`
# * Outer loop starts: `for i in range(0, num)`
# * Since `num` is a list, `range(0, num)` raises `TypeError: 'list' object cannot be interpreted as an integer`.
# * Execution crashes before sorting.
#
# ## Time Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #d9534f; background-color: #f2dede; color: #a94442; margin: 10px 0;">
#   <strong>Time Complexity:</strong> <span style="color: #d9534f; font-weight: bold;">O(N^2)</span> &mdash; If fixed to `range(0, n)`, the nested comparisons check all pairs.
# </div>
#
# ## Space Complexity
#
# <div style="padding: 8px 12px; border-left: 4px solid #5cb85c; background-color: #dff0d8; color: #3c763d; margin: 10px 0;">
#   <strong>Space Complexity:</strong> <span style="color: #5cb85c; font-weight: bold;">O(1)</span> &mdash; Operations are performed in-place.
# </div>
