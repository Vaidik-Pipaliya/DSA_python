# %%
item=["apple","banana","mango","graps"]
item.append("pitch")
for a in item:
    print("current items")
    print(f"-{a}")
# Out:
# current items
# -apple
# current items
# -banana
# current items
# -mango
# current items
# -graps
# current items
# -pitch

# %%
item.remove("banana")
fruit = "mango"
if fruit in item:
    print(f"{fruit} is available")
else:
    print("not avilable")
print("inventory list:-")
for i in item:
    print(f"-{i}")
# Out:
# mango is available
# inventory list:-
# -apple
# -mango
# -graps
# -pitch
