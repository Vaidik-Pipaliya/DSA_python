# %% [markdown]
# ## syntax:
# def func_name(paramaters):
#     #logics
#     return expression

# %%
num = 24
if num%2==0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
#now we will make function
# Out:
# 24 is even

# %%
def even_odd(num):
    """this will finds even or odd nummbers"""
    if num%2==0:
        print(f"{num} is even")
    else:
        print(f"{num} is odd")

# %%
##calling function
even_odd(5)
# Out:
# 5 is odd

# %%
def sum(a,b):
    return a+b


result = sum(1,2)
print(f"{result}")
# Out:
# 3

# %%
##multiple para
